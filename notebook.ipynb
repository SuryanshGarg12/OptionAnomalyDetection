# %%
# import
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import os
from typing import Dict, Tuple, List, Optional, Union, Callable
import warnings
warnings.filterwarnings('ignore')

# %%
# create output folders
os.makedirs("anomaly_plots", exist_ok=True)

def load_and_preprocess_data(file_path: str) -> pd.DataFrame:
    """
    Load options data from parquet file and perform preprocessing

    Args:
        file_path: Path to the parquet file

    Returns:
        Preprocessed DataFrame
    """
    df = pd.read_parquet(file_path)

    if not isinstance(df.index, pd.DatetimeIndex):
        try:
            df.index = pd.to_datetime(df.index)
        except:
            print("Warning: Could not convert index to datetime, using as-is")

    for col in df.columns:
        df[col] = df[col].ffill(limit=5)

    print(f"Data timeframe: {df.index[0]} to {df.index[-1]}")

    return df

# %%
def bs_price(S: pd.Series, K: float, T: pd.Series, r: float, sigma: pd.Series, option_type: str) -> pd.Series:
    """
    Calculate Black-Scholes option price

    Args:
        S: Underlying price series
        K: Strike price
        T: Time to expiry in years
        r: Risk-free rate
        sigma: Implied volatility series
        option_type: 'call' or 'put'

    Returns:
        Option price series
    """
    idx = S.index
    S_arr = S.values
    T_arr = T.values
    sigma_arr = sigma.values

    S_arr = np.asarray(S_arr, dtype=np.float64)
    T_arr = np.asarray(T_arr, dtype=np.float64)
    sigma_arr = np.asarray(sigma_arr, dtype=np.float64)
    
    mask = (sigma_arr > 0) & (T_arr > 0) & (S_arr > 0)
    
    d1 = np.full_like(S_arr, np.nan, dtype=np.float64)
    d2 = np.full_like(S_arr, np.nan, dtype=np.float64)
    price = np.full_like(S_arr, np.nan, dtype=np.float64)

    d1[mask] = (
        np.log(S_arr[mask] / K)
        + (r + 0.5 * sigma_arr[mask]**2) * T_arr[mask]
    ) / (sigma_arr[mask] * np.sqrt(T_arr[mask]))
    
    d2[mask] = d1[mask] - sigma_arr[mask] * np.sqrt(T_arr[mask])

    if option_type.lower() == 'call':
        price[mask] = S_arr[mask] * norm.cdf(d1[mask]) - K * np.exp(-r * T_arr[mask]) * norm.cdf(d2[mask])
    else:
        price[mask] = K * np.exp(-r * T_arr[mask]) * norm.cdf(-d2[mask]) - S_arr[mask] * norm.cdf(-d1[mask])

    return pd.Series(price, index=idx)

def calculate_price_jump(price: pd.Series, window: int = 5) -> pd.Series:
    """Calculate price jumps as percentage changes over specified window"""
    return price.pct_change(window).abs()

def calculate_spread_width(bid: pd.Series, ask: pd.Series) -> pd.Series:
    """Calculate bid-ask spread as percentage of mid price"""
    mid = (bid + ask) / 2
    return (ask - bid) / mid

def calculate_z_score(series: pd.Series, window: int = 60, min_periods: int = 10) -> pd.Series:
    """Calculate z-score for a time series using rolling window"""
    mean = series.rolling(window, min_periods=min_periods).mean()
    std = series.rolling(window, min_periods=min_periods).std()

    # for cases where std is 0 or NaN
    std = std.replace(0, series.std() if series.std() > 0 else 1e-6)
    std = std.fillna(series.std() if series.std() > 0 else 1e-6)

    return (series - mean) / std

# %%
def detect_anomalies(df: pd.DataFrame,
                    threshold: float = 3.0,
                    r: float = 0.0588,  # risk-free rate
                    window_size: int = 60,
                    plot_anomalies: bool = True) -> Tuple[pd.DataFrame, Dict]:
    """
    Detect anomalies in options data

    Args:
        df: DataFrame with options data
        threshold: Z-score threshold for anomaly detection
        r: Risk-free rate for BS model
        window_size: Window size for rolling statistics
        plot_anomalies: Whether to create plots

    Returns:
        Tuple of (anomalies DataFrame, results dictionary)
    """
    anomalies = []

    # filter out columns that are not actual instruments
    instruments = [col for col in df.columns.get_level_values(1).unique()
                if '_' in col and (col.endswith('CE') or col.endswith('PE'))]
    print(f"Found {len(instruments)} valid option instruments")

    detection_results = {}

    for inst in instruments:
        try:
            bid = df.get(('best_bid', inst), pd.Series(index=df.index, dtype=float))
            ask = df.get(('best_offer', inst), pd.Series(index=df.index, dtype=float))
            iv = df.get(('iv', inst), pd.Series(index=df.index, dtype=float))
            S = df.get(('additional', 'underlying_price'), pd.Series(index=df.index, dtype=float))
            T = df.get(('additional', 'tte'), pd.Series(index=df.index, dtype=float))
            gamma = df.get(('gamma', inst), pd.Series(index=df.index, dtype=float))

            # align indexes & NaN handling
            bid = bid.reindex(df.index).fillna(method='ffill', limit=5)
            ask = ask.reindex(df.index).fillna(method='ffill', limit=5)
            iv = iv.reindex(df.index).fillna(method='ffill', limit=5)
            S = S.reindex(df.index).fillna(method='ffill')
            T = T.reindex(df.index).fillna(method='ffill')
            gamma = gamma.reindex(df.index).fillna(method='ffill', limit=5).fillna(0)

            # for too many NaN values
            if (bid.isna().sum() > 0.5 * len(bid)) or (ask.isna().sum() > 0.5 * len(ask)):
                print(f"Skipping {inst} due to insufficient data")
                continue

            mid = (bid + ask) / 2

            parts = inst.split('_')
            if len(parts) < 3:
                print(f"Skipping {inst}: invalid instrument name format")
                continue

            try:
                strike = float(parts[2])
                option_type = 'call' if inst.endswith('CE') else 'put'
                expiry = parts[1]
            except:
                print(f"Skipping {inst}: could not parse strike price")
                continue

            # feature 1: mispricing
            theory = bs_price(S, strike, T, r, iv, option_type)
            mispricing = (mid - theory).abs()
            mispricing_pct = mispricing / theory
            z_mis = calculate_z_score(mispricing, window=window_size)

            # feature 2: iv changes
            z_iv = calculate_z_score(iv, window=window_size)

            # feature 3: price jumps
            price_jump = calculate_price_jump(mid, window=5)
            z_price_jump = calculate_z_score(price_jump, window=window_size)

            # feature 4: spread widening
            spread = calculate_spread_width(bid, ask)
            z_spread = calculate_z_score(spread, window=window_size)

            # feature 5: gamma spikes
            z_gamma = calculate_z_score(gamma, window=window_size)

            iv_spike_mask = (z_iv > threshold).fillna(False)
            mispricing_mask = (z_mis > threshold).fillna(False)
            price_jump_mask = (z_price_jump > threshold).fillna(False)
            spread_widening_mask = (z_spread > threshold).fillna(False)
            gamma_spike_mask = (z_gamma > threshold).fillna(False)

            detection_results[inst] = {
                'iv_spike_mask': iv_spike_mask,
                'mispricing_mask': mispricing_mask,
                'price_jump_mask': price_jump_mask,
                'spread_widening_mask': spread_widening_mask,
                'gamma_spike_mask': gamma_spike_mask,
                'iv': iv,
                'mid': mid,
                'bid': bid,
                'ask': ask,
                'spread': spread,
                'theory': theory,
                'mispricing_pct': mispricing_pct,
                'gamma': gamma,
                'z_iv': z_iv,
                'z_spread': z_spread,
                'z_gamma': z_gamma,
                'z_price_jump': z_price_jump,
                'expiry': expiry,
                'option_type': option_type,
                'strike': strike
            }

            has_anomalies = (
                iv_spike_mask.sum() > 0 or
                mispricing_mask.sum() > 0 or
                price_jump_mask.sum() > 0 or
                spread_widening_mask.sum() > 0 or
                gamma_spike_mask.sum() > 0
            )

            if has_anomalies:
                print(f"{inst}: IV spikes: {iv_spike_mask.sum()}, "
                      f"Mispricings: {mispricing_mask.sum()}, "
                      f"Price jumps: {price_jump_mask.sum()}, "
                      f"Spread widenings: {spread_widening_mask.sum()}, "
                      f"Gamma spikes: {gamma_spike_mask.sum()}")

            for ts in iv_spike_mask[iv_spike_mask].index:
                anomalies.append((ts, inst, "IV spike", round(float(z_iv.loc[ts]), 2)))

            for ts in mispricing_mask[mispricing_mask].index:
                anomalies.append((ts, inst, "Mispricing", f"{round(float(mispricing_pct.loc[ts]*100), 2)}%"))

            for ts in price_jump_mask[price_jump_mask].index:
                anomalies.append((ts, inst, "Price jump", f"{round(float(price_jump.loc[ts]*100), 2)}%"))

            for ts in spread_widening_mask[spread_widening_mask].index:
                anomalies.append((ts, inst, "Spread widening", round(float(z_spread.loc[ts]), 2)))

            for ts in gamma_spike_mask[gamma_spike_mask].index:
                anomalies.append((ts, inst, "Gamma spike", round(float(z_gamma.loc[ts]), 2)))

            # plots
            if has_anomalies and plot_anomalies:
                fig, axs = plt.subplots(5, 1, figsize=(14, 18), sharex=True)
                plot_idx = df.index

                axs[0].plot(plot_idx, iv, label="IV", linewidth=1, marker='.', markersize=1)
                axs[0].scatter(plot_idx[iv_spike_mask],
                              iv[iv_spike_mask],
                              color='red', label="IV Spike", s=30)
                axs[0].set_ylabel("IV")
                axs[0].legend(loc='upper right')
                axs[0].grid(True, alpha=0.3)

                axs[1].plot(plot_idx, mid, label="Mid Price", linewidth=1, marker='.', markersize=1)
                axs[1].plot(plot_idx, theory, label="BS Price", linestyle='--', linewidth=1)
                axs[1].scatter(plot_idx[mispricing_mask],
                              mid[mispricing_mask],
                              color='purple', label="Mispricing", s=30)
                axs[1].set_ylabel("Price")
                axs[1].legend(loc='upper right')
                axs[1].grid(True, alpha=0.3)

                axs[2].plot(plot_idx, price_jump * 100, label="Price Jump %", linewidth=1, marker='.', markersize=1)
                axs[2].scatter(plot_idx[price_jump_mask],
                              price_jump[price_jump_mask] * 100,
                              color='green', label="Jump Anomaly", s=30)
                axs[2].set_ylabel("Price Jump %")
                axs[2].legend(loc='upper right')
                axs[2].grid(True, alpha=0.3)

                axs[3].plot(plot_idx, spread * 100, label="Spread %", linewidth=1, marker='.', markersize=1)
                axs[3].scatter(plot_idx[spread_widening_mask],
                              spread[spread_widening_mask] * 100,
                              color='blue', label="Spread Widening", s=30)
                axs[3].set_ylabel("Spread %")
                axs[3].legend(loc='upper right')
                axs[3].grid(True, alpha=0.3)

                axs[4].plot(plot_idx, gamma, label="Gamma", linewidth=1, marker='.', markersize=1)
                axs[4].scatter(plot_idx[gamma_spike_mask],
                              gamma[gamma_spike_mask],
                              color='magenta', label="Gamma Spike", s=30)
                axs[4].set_ylabel("Gamma")
                axs[4].legend(loc='upper right')
                axs[4].grid(True, alpha=0.3)

                date_fmt = mdates.DateFormatter('%H:%M')
                axs[4].xaxis.set_major_locator(mdates.HourLocator(interval=1))
                axs[4].xaxis.set_major_formatter(date_fmt)
                axs[4].xaxis.set_minor_locator(mdates.MinuteLocator(byminute=[15,30,45]))

                plt.gcf().autofmt_xdate()

                for ax in axs:
                    ax.xaxis.set_tick_params(rotation=45)
                plt.subplots_adjust(hspace=0.3)
                trading_date = plot_idx[0].strftime('%Y-%m-%d')
                fig.suptitle(f"Anomalies for {inst} (Date: {trading_date})", fontsize=14)

                plt.tight_layout()
                plt.savefig(f"anomaly_plots/{inst}.png")
                plt.close()

        except Exception as e:
            print(f"Error processing {inst}: {e}")
            continue

    if anomalies:
        anomalies_df = pd.DataFrame(anomalies, columns=["timestamp", "instrument", "anomaly_type", "value"])
        anomalies_df = anomalies_df.sort_values(["timestamp", "instrument"])
    else:
        anomalies_df = pd.DataFrame(columns=["timestamp", "instrument", "anomaly_type", "value"])

    return anomalies_df, detection_results

# %%
""" Note that the summary and result csv files and plots are for ad1.parquet in order to get results for 
    ad2.parquet replace the data_file below and run this cell """


data_file = "ad1.parquet"
df = load_and_preprocess_data(data_file)

print("\nColumn structure:")
print(f"Level 0 (metrics): {df.columns.get_level_values(0).unique()}")
print(f"Level 1 (instruments): {len(df.columns.get_level_values(1).unique())} unique values")

anomalies_df, detection_results = detect_anomalies(df, threshold=3.0, plot_anomalies=True)
anomalies_df.to_csv("anomaly_results.csv", index=False)

# summary
if not anomalies_df.empty:
    anomaly_summary = anomalies_df.groupby(['instrument','anomaly_type']).size().reset_index(name='count')
    anomaly_summary = anomaly_summary.sort_values(['instrument','count'], ascending=[True,False])
    anomaly_summary.to_csv("anomaly_summary.csv", index=False)

    anomaly_type_summary = anomalies_df.groupby('anomaly_type').size().reset_index(name='count')
    anomaly_type_summary = anomaly_type_summary.sort_values('count', ascending=False)
    anomaly_type_summary.to_csv("anomaly_type_summary.csv", index=False)

    print(f"\nDetected {len(anomalies_df)} individual anomalies")

print("\nPlots saved in ./anomaly_plots/")
print("Results saved in anomaly_results.csv and anomaly_summary.csv")
# Out:
# Data timeframe: 2025-01-13 09:15:00 to 2025-01-13 15:30:00
#
# Column structure:
# Level 0 (metrics): Index(['best_bid', 'best_offer', 'ltp', 'traded_volume', 'additional',
#        'bid_iv', 'ask_iv', 'iv', 'iv_ema60', 'iv7', 'iv7_ema60', 'delta',
#        'gamma', 'theta', 'vega'],
#       dtype='object')
# Level 1 (instruments): 162 unique values
# Found 156 valid option instruments
# X_25123_21800_CE: IV spikes: 212, Mispricings: 254, Price jumps: 185, Spread widenings: 90, Gamma spikes: 488
# X_25123_21800_PE: IV spikes: 339, Mispricings: 278, Price jumps: 395, Spread widenings: 176, Gamma spikes: 133
# X_25123_21850_CE: IV spikes: 191, Mispricings: 320, Price jumps: 284, Spread widenings: 165, Gamma spikes: 508
# X_25123_21850_PE: IV spikes: 319, Mispricings: 466, Price jumps: 745, Spread widenings: 383, Gamma spikes: 138
# X_25123_21900_CE: IV spikes: 230, Mispricings: 238, Price jumps: 258, Spread widenings: 139, Gamma spikes: 545
# X_25123_21900_PE: IV spikes: 339, Mispricings: 342, Price jumps: 429, Spread widenings: 216, Gamma spikes: 137
# X_25123_21950_CE: IV spikes: 219, Mispricings: 313, Price jumps: 260, Spread widenings: 146, Gamma spikes: 570
# X_25123_21950_PE: IV spikes: 310, Mispricings: 380, Price jumps: 610, Spread widenings: 318, Gamma spikes: 155
# X_25123_22000_CE: IV spikes: 339, Mispricings: 260, Price jumps: 625, Spread widenings: 300, Gamma spikes: 788
# X_25123_22000_PE: IV spikes: 277, Mispricings: 486, Price jumps: 976, Spread widenings: 532, Gamma spikes: 141
# X_25123_22050_CE: IV spikes: 238, Mispricings: 269, Price jumps: 531, Spread widenings: 283, Gamma spikes: 791
# X_25123_22050_PE: IV spikes: 302, Mispricings: 411, Price jumps: 853, Spread widenings: 491, Gamma spikes: 160
# X_25123_22100_CE: IV spikes: 273, Mispricings: 264, Price jumps: 233, Spread widenings: 110, Gamma spikes: 599
# X_25123_22100_PE: IV spikes: 317, Mispricings: 421, Price jumps: 867, Spread widenings: 511, Gamma spikes: 142
# X_25123_22150_CE: IV spikes: 260, Mispricings: 274, Price jumps: 401, Spread widenings: 194, Gamma spikes: 635
# X_25123_22150_PE: IV spikes: 276, Mispricings: 452, Price jumps: 875, Spread widenings: 437, Gamma spikes: 162
# X_25123_22200_CE: IV spikes: 322, Mispricings: 411, Price jumps: 190, Spread widenings: 90, Gamma spikes: 660
# X_25123_22200_PE: IV spikes: 284, Mispricings: 435, Price jumps: 972, Spread widenings: 471, Gamma spikes: 139
# X_25123_22250_CE: IV spikes: 231, Mispricings: 430, Price jumps: 294, Spread widenings: 181, Gamma spikes: 537
# X_25123_22250_PE: IV spikes: 262, Mispricings: 435, Price jumps: 962, Spread widenings: 496, Gamma spikes: 141
# X_25123_22300_CE: IV spikes: 299, Mispricings: 387, Price jumps: 200, Spread widenings: 108, Gamma spikes: 562
# X_25123_22300_PE: IV spikes: 299, Mispricings: 470, Price jumps: 1023, Spread widenings: 518, Gamma spikes: 141
# X_25123_22350_CE: IV spikes: 296, Mispricings: 537, Price jumps: 492, Spread widenings: 280, Gamma spikes: 590
# X_25123_22350_PE: IV spikes: 289, Mispricings: 457, Price jumps: 919, Spread widenings: 476, Gamma spikes: 150
# X_25123_22400_CE: IV spikes: 216, Mispricings: 483, Price jumps: 140, Spread widenings: 69, Gamma spikes: 382
# X_25123_22400_PE: IV spikes: 287, Mispricings: 420, Price jumps: 993, Spread widenings: 521, Gamma spikes: 146
# X_25123_22450_CE: IV spikes: 143, Mispricings: 675, Price jumps: 370, Spread widenings: 190, Gamma spikes: 278
# X_25123_22450_PE: IV spikes: 269, Mispricings: 437, Price jumps: 960, Spread widenings: 567, Gamma spikes: 140
# X_25123_22500_CE: IV spikes: 89, Mispricings: 424, Price jumps: 921, Spread widenings: 467, Gamma spikes: 144
# X_25123_22500_PE: IV spikes: 235, Mispricings: 416, Price jumps: 1083, Spread widenings: 503, Gamma spikes: 150
# X_25123_22550_CE: IV spikes: 148, Mispricings: 586, Price jumps: 931, Spread widenings: 529, Gamma spikes: 136
# X_25123_22550_PE: IV spikes: 250, Mispricings: 393, Price jumps: 927, Spread widenings: 467, Gamma spikes: 154
# X_25123_22600_CE: IV spikes: 155, Mispricings: 493, Price jumps: 423, Spread widenings: 247, Gamma spikes: 162
# X_25123_22600_PE: IV spikes: 281, Mispricings: 371, Price jumps: 996, Spread widenings: 422, Gamma spikes: 154
# X_25123_22650_CE: IV spikes: 99, Mispricings: 474, Price jumps: 1076, Spread widenings: 516, Gamma spikes: 144
# X_25123_22650_PE: IV spikes: 299, Mispricings: 334, Price jumps: 878, Spread widenings: 479, Gamma spikes: 156
# X_25123_22700_CE: IV spikes: 125, Mispricings: 329, Price jumps: 1064, Spread widenings: 586, Gamma spikes: 149
# X_25123_22700_PE: IV spikes: 265, Mispricings: 319, Price jumps: 998, Spread widenings: 440, Gamma spikes: 151
# X_25123_22750_CE: IV spikes: 149, Mispricings: 321, Price jumps: 1040, Spread widenings: 590, Gamma spikes: 135
# X_25123_22750_PE: IV spikes: 297, Mispricings: 331, Price jumps: 999, Spread widenings: 455, Gamma spikes: 149
# X_25123_22800_CE: IV spikes: 159, Mispricings: 304, Price jumps: 1013, Spread widenings: 580, Gamma spikes: 116
# X_25123_22800_PE: IV spikes: 255, Mispricings: 313, Price jumps: 1060, Spread widenings: 475, Gamma spikes: 160
# X_25123_22850_CE: IV spikes: 153, Mispricings: 317, Price jumps: 974, Spread widenings: 486, Gamma spikes: 123
# X_25123_22850_PE: IV spikes: 255, Mispricings: 298, Price jumps: 951, Spread widenings: 518, Gamma spikes: 149
# X_25123_22900_CE: IV spikes: 158, Mispricings: 319, Price jumps: 880, Spread widenings: 501, Gamma spikes: 136
# X_25123_22900_PE: IV spikes: 276, Mispricings: 285, Price jumps: 1053, Spread widenings: 525, Gamma spikes: 152
# X_25123_22950_CE: IV spikes: 167, Mispricings: 298, Price jumps: 871, Spread widenings: 472, Gamma spikes: 165
# X_25123_22950_PE: IV spikes: 258, Mispricings: 226, Price jumps: 898, Spread widenings: 493, Gamma spikes: 161
# X_25123_23000_CE: IV spikes: 151, Mispricings: 311, Price jumps: 991, Spread widenings: 509, Gamma spikes: 159
# X_25123_23000_PE: IV spikes: 255, Mispricings: 237, Price jumps: 1103, Spread widenings: 586, Gamma spikes: 158
# X_25123_23050_CE: IV spikes: 134, Mispricings: 319, Price jumps: 943, Spread widenings: 532, Gamma spikes: 211
# X_25123_23050_PE: IV spikes: 333, Mispricings: 207, Price jumps: 815, Spread widenings: 414, Gamma spikes: 192
# X_25123_23100_CE: IV spikes: 147, Mispricings: 321, Price jumps: 889, Spread widenings: 462, Gamma spikes: 277
# X_25123_23100_PE: IV spikes: 251, Mispricings: 212, Price jumps: 1019, Spread widenings: 497, Gamma spikes: 157
# X_25123_23150_CE: IV spikes: 130, Mispricings: 335, Price jumps: 932, Spread widenings: 424, Gamma spikes: 243
# X_25123_23150_PE: IV spikes: 299, Mispricings: 166, Price jumps: 934, Spread widenings: 474, Gamma spikes: 175
# X_25123_23200_CE: IV spikes: 134, Mispricings: 296, Price jumps: 997, Spread widenings: 512, Gamma spikes: 240
# X_25123_23200_PE: IV spikes: 225, Mispricings: 169, Price jumps: 1085, Spread widenings: 535, Gamma spikes: 162
# X_25123_23250_CE: IV spikes: 113, Mispricings: 305, Price jumps: 1042, Spread widenings: 495, Gamma spikes: 300
# X_25123_23250_PE: IV spikes: 307, Mispricings: 150, Price jumps: 921, Spread widenings: 447, Gamma spikes: 173
# X_25123_23300_CE: IV spikes: 126, Mispricings: 317, Price jumps: 993, Spread widenings: 406, Gamma spikes: 244
# X_25123_23300_PE: IV spikes: 268, Mispricings: 153, Price jumps: 988, Spread widenings: 484, Gamma spikes: 216
# X_25123_23350_CE: IV spikes: 148, Mispricings: 309, Price jumps: 947, Spread widenings: 466, Gamma spikes: 295
# X_25123_23350_PE: IV spikes: 299, Mispricings: 162, Price jumps: 1025, Spread widenings: 530, Gamma spikes: 119
# X_25123_23400_CE: IV spikes: 146, Mispricings: 317, Price jumps: 970, Spread widenings: 496, Gamma spikes: 278
# X_25123_23400_PE: IV spikes: 245, Mispricings: 167, Price jumps: 1042, Spread widenings: 529, Gamma spikes: 131
# X_25123_23450_CE: IV spikes: 142, Mispricings: 304, Price jumps: 946, Spread widenings: 503, Gamma spikes: 281
# X_25123_23450_PE: IV spikes: 260, Mispricings: 167, Price jumps: 957, Spread widenings: 533, Gamma spikes: 152
# X_25123_23500_CE: IV spikes: 156, Mispricings: 286, Price jumps: 1034, Spread widenings: 415, Gamma spikes: 327
# X_25123_23500_PE: IV spikes: 262, Mispricings: 147, Price jumps: 966, Spread widenings: 471, Gamma spikes: 133
# X_25123_23550_CE: IV spikes: 115, Mispricings: 326, Price jumps: 1053, Spread widenings: 553, Gamma spikes: 275
# X_25123_23550_PE: IV spikes: 285, Mispricings: 158, Price jumps: 1020, Spread widenings: 517, Gamma spikes: 175
# X_25123_23600_CE: IV spikes: 106, Mispricings: 342, Price jumps: 1029, Spread widenings: 501, Gamma spikes: 265
# X_25123_23600_PE: IV spikes: 246, Mispricings: 170, Price jumps: 1058, Spread widenings: 552, Gamma spikes: 176
# X_25123_23650_CE: IV spikes: 153, Mispricings: 338, Price jumps: 1022, Spread widenings: 545, Gamma spikes: 287
# X_25123_23650_PE: IV spikes: 296, Mispricings: 152, Price jumps: 973, Spread widenings: 518, Gamma spikes: 206
# X_25123_23700_CE: IV spikes: 111, Mispricings: 329, Price jumps: 993, Spread widenings: 505, Gamma spikes: 311
# X_25123_23700_PE: IV spikes: 282, Mispricings: 142, Price jumps: 920, Spread widenings: 460, Gamma spikes: 190
# X_25123_23750_CE: IV spikes: 124, Mispricings: 361, Price jumps: 962, Spread widenings: 469, Gamma spikes: 299
# X_25123_23750_PE: IV spikes: 247, Mispricings: 190, Price jumps: 964, Spread widenings: 556, Gamma spikes: 228
# X_25123_23800_CE: IV spikes: 133, Mispricings: 415, Price jumps: 1071, Spread widenings: 594, Gamma spikes: 308
# X_25123_23800_PE: IV spikes: 275, Mispricings: 161, Price jumps: 910, Spread widenings: 537, Gamma spikes: 270
# X_25123_23850_CE: IV spikes: 140, Mispricings: 382, Price jumps: 1074, Spread widenings: 564, Gamma spikes: 303
# X_25123_23850_PE: IV spikes: 263, Mispricings: 210, Price jumps: 915, Spread widenings: 467, Gamma spikes: 246
# X_25123_23900_CE: IV spikes: 161, Mispricings: 365, Price jumps: 950, Spread widenings: 528, Gamma spikes: 309
# X_25123_23900_PE: IV spikes: 312, Mispricings: 207, Price jumps: 750, Spread widenings: 439, Gamma spikes: 276
# X_25123_23950_CE: IV spikes: 132, Mispricings: 352, Price jumps: 983, Spread widenings: 581, Gamma spikes: 300
# X_25123_23950_PE: IV spikes: 264, Mispricings: 299, Price jumps: 928, Spread widenings: 519, Gamma spikes: 280
# X_25123_24000_CE: IV spikes: 143, Mispricings: 406, Price jumps: 1019, Spread widenings: 545, Gamma spikes: 304
# X_25123_24000_PE: IV spikes: 239, Mispricings: 176, Price jumps: 976, Spread widenings: 541, Gamma spikes: 293
# X_25123_24050_CE: IV spikes: 112, Mispricings: 415, Price jumps: 985, Spread widenings: 578, Gamma spikes: 307
# X_25123_24050_PE: IV spikes: 237, Mispricings: 294, Price jumps: 879, Spread widenings: 471, Gamma spikes: 262
# X_25123_24100_CE: IV spikes: 139, Mispricings: 395, Price jumps: 1039, Spread widenings: 562, Gamma spikes: 319
# X_25123_24100_PE: IV spikes: 249, Mispricings: 186, Price jumps: 1039, Spread widenings: 551, Gamma spikes: 292
# X_25123_24150_CE: IV spikes: 121, Mispricings: 373, Price jumps: 932, Spread widenings: 547, Gamma spikes: 301
# X_25123_24150_PE: IV spikes: 235, Mispricings: 357, Price jumps: 795, Spread widenings: 404, Gamma spikes: 284
# X_25123_24200_CE: IV spikes: 154, Mispricings: 352, Price jumps: 998, Spread widenings: 498, Gamma spikes: 304
# X_25123_24200_PE: IV spikes: 241, Mispricings: 260, Price jumps: 879, Spread widenings: 485, Gamma spikes: 241
# X_25123_24250_CE: IV spikes: 163, Mispricings: 446, Price jumps: 870, Spread widenings: 484, Gamma spikes: 298
# X_25123_24250_PE: IV spikes: 260, Mispricings: 271, Price jumps: 851, Spread widenings: 472, Gamma spikes: 268
# X_25123_24300_CE: IV spikes: 154, Mispricings: 414, Price jumps: 740, Spread widenings: 387, Gamma spikes: 291
# X_25123_24300_PE: IV spikes: 230, Mispricings: 344, Price jumps: 795, Spread widenings: 440, Gamma spikes: 228
# X_25123_24350_CE: IV spikes: 147, Mispricings: 367, Price jumps: 885, Spread widenings: 470, Gamma spikes: 300
# X_25123_24350_PE: IV spikes: 290, Mispricings: 275, Price jumps: 497, Spread widenings: 239, Gamma spikes: 476
# X_25123_24400_CE: IV spikes: 152, Mispricings: 394, Price jumps: 561, Spread widenings: 291, Gamma spikes: 292
# X_25123_24400_PE: IV spikes: 260, Mispricings: 301, Price jumps: 735, Spread widenings: 389, Gamma spikes: 285
# X_25123_24450_CE: IV spikes: 152, Mispricings: 429, Price jumps: 805, Spread widenings: 417, Gamma spikes: 301
# X_25123_24450_PE: IV spikes: 247, Mispricings: 316, Price jumps: 832, Spread widenings: 423, Gamma spikes: 326
# X_25123_24500_CE: IV spikes: 171, Mispricings: 410, Price jumps: 736, Spread widenings: 399, Gamma spikes: 289
# X_25123_24500_PE: IV spikes: 212, Mispricings: 252, Price jumps: 847, Spread widenings: 422, Gamma spikes: 287
# X_25123_24550_CE: IV spikes: 171, Mispricings: 445, Price jumps: 754, Spread widenings: 364, Gamma spikes: 287
# X_25123_24550_PE: IV spikes: 219, Mispricings: 251, Price jumps: 878, Spread widenings: 433, Gamma spikes: 332
# X_25123_24600_CE: IV spikes: 152, Mispricings: 357, Price jumps: 417, Spread widenings: 233, Gamma spikes: 295
# X_25123_24600_PE: IV spikes: 314, Mispricings: 284, Price jumps: 281, Spread widenings: 121, Gamma spikes: 502
# X_25123_24650_CE: IV spikes: 161, Mispricings: 406, Price jumps: 460, Spread widenings: 272, Gamma spikes: 287
# X_25123_24650_PE: IV spikes: 262, Mispricings: 304, Price jumps: 522, Spread widenings: 300, Gamma spikes: 351
# X_25123_24700_CE: IV spikes: 183, Mispricings: 376, Price jumps: 354, Spread widenings: 198, Gamma spikes: 285
# X_25123_24700_PE: IV spikes: 302, Mispricings: 217, Price jumps: 235, Spread widenings: 115, Gamma spikes: 465
# X_25123_24750_CE: IV spikes: 166, Mispricings: 345, Price jumps: 330, Spread widenings: 180, Gamma spikes: 296
# X_25123_24750_PE: IV spikes: 292, Mispricings: 414, Price jumps: 523, Spread widenings: 284, Gamma spikes: 474
# X_25123_24800_CE: IV spikes: 159, Mispricings: 356, Price jumps: 345, Spread widenings: 175, Gamma spikes: 285
# X_25123_24800_PE: IV spikes: 336, Mispricings: 290, Price jumps: 261, Spread widenings: 129, Gamma spikes: 610
# X_25123_24850_CE: IV spikes: 163, Mispricings: 353, Price jumps: 179, Spread widenings: 77, Gamma spikes: 289
# X_25123_24850_PE: IV spikes: 302, Mispricings: 367, Price jumps: 603, Spread widenings: 310, Gamma spikes: 419
# X_25123_24900_CE: IV spikes: 167, Mispricings: 364, Price jumps: 241, Spread widenings: 121, Gamma spikes: 287
# X_25123_24900_PE: IV spikes: 295, Mispricings: 325, Price jumps: 180, Spread widenings: 90, Gamma spikes: 534
# X_25123_24950_CE: IV spikes: 168, Mispricings: 345, Price jumps: 187, Spread widenings: 84, Gamma spikes: 275
# X_25123_24950_PE: IV spikes: 293, Mispricings: 346, Price jumps: 536, Spread widenings: 307, Gamma spikes: 435
# X_25123_25000_CE: IV spikes: 164, Mispricings: 372, Price jumps: 234, Spread widenings: 115, Gamma spikes: 296
# X_25123_25000_PE: IV spikes: 383, Mispricings: 394, Price jumps: 630, Spread widenings: 355, Gamma spikes: 524
# X_25123_25050_CE: IV spikes: 188, Mispricings: 381, Price jumps: 320, Spread widenings: 175, Gamma spikes: 299
# X_25123_25050_PE: IV spikes: 370, Mispricings: 469, Price jumps: 298, Spread widenings: 140, Gamma spikes: 616
# X_25123_25100_CE: IV spikes: 198, Mispricings: 372, Price jumps: 247, Spread widenings: 120, Gamma spikes: 295
# X_25123_25100_PE: IV spikes: 365, Mispricings: 439, Price jumps: 230, Spread widenings: 125, Gamma spikes: 657
# X_25123_25150_CE: IV spikes: 197, Mispricings: 405, Price jumps: 319, Spread widenings: 156, Gamma spikes: 298
# X_25123_25150_PE: IV spikes: 424, Mispricings: 387, Price jumps: 294, Spread widenings: 150, Gamma spikes: 702
# X_25123_25200_CE: IV spikes: 200, Mispricings: 402, Price jumps: 285, Spread widenings: 113, Gamma spikes: 298
# X_25123_25200_PE: IV spikes: 358, Mispricings: 335, Price jumps: 150, Spread widenings: 80, Gamma spikes: 550
# X_25123_25250_CE: IV spikes: 164, Mispricings: 290, Price jumps: 110, Spread widenings: 55, Gamma spikes: 241
# X_25123_25250_PE: IV spikes: 386, Mispricings: 326, Price jumps: 205, Spread widenings: 120, Gamma spikes: 601
# X_25123_25300_CE: IV spikes: 190, Mispricings: 341, Price jumps: 191, Spread widenings: 90, Gamma spikes: 264
# X_25123_25300_PE: IV spikes: 352, Mispricings: 341, Price jumps: 205, Spread widenings: 91, Gamma spikes: 566
# X_25123_25350_CE: IV spikes: 168, Mispricings: 249, Price jumps: 137, Spread widenings: 75, Gamma spikes: 205
# X_25123_25350_PE: IV spikes: 438, Mispricings: 391, Price jumps: 230, Spread widenings: 115, Gamma spikes: 654
# X_25123_25400_CE: IV spikes: 197, Mispricings: 346, Price jumps: 306, Spread widenings: 140, Gamma spikes: 313
# X_25123_25400_PE: IV spikes: 319, Mispricings: 291, Price jumps: 99, Spread widenings: 55, Gamma spikes: 461
# X_25123_25450_CE: IV spikes: 190, Mispricings: 322, Price jumps: 115, Spread widenings: 50, Gamma spikes: 265
# X_25123_25450_PE: IV spikes: 414, Mispricings: 433, Price jumps: 205, Spread widenings: 114, Gamma spikes: 603
# X_25123_25500_CE: IV spikes: 215, Mispricings: 430, Price jumps: 350, Spread widenings: 185, Gamma spikes: 284
# X_25123_25500_PE: IV spikes: 341, Mispricings: 346, Price jumps: 492, Spread widenings: 237, Gamma spikes: 467
# X_25123_25550_CE: IV spikes: 206, Mispricings: 395, Price jumps: 285, Spread widenings: 155, Gamma spikes: 281
# X_25123_25550_PE: IV spikes: 367, Mispricings: 419, Price jumps: 205, Spread widenings: 125, Gamma spikes: 540
# X_25123_25600_CE: IV spikes: 201, Mispricings: 385, Price jumps: 260, Spread widenings: 130, Gamma spikes: 297
# X_25123_25600_PE: IV spikes: 384, Mispricings: 382, Price jumps: 180, Spread widenings: 84, Gamma spikes: 581
# X_25123_25650_CE: IV spikes: 232, Mispricings: 408, Price jumps: 352, Spread widenings: 168, Gamma spikes: 295
# X_25123_25650_PE: IV spikes: 386, Mispricings: 415, Price jumps: 262, Spread widenings: 135, Gamma spikes: 621
#
# Detected 299478 individual anomalies
#
# Plots saved in ./anomaly_plots/
# Results saved in anomaly_results.csv and anomaly_summary.csv
